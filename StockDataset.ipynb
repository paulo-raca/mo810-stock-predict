# %%
from stock_dataset import *

# %%
minibatch_producer(timeseries_length=1, minibatch_size=1, num_companies=1)()
# Out:
# array([[[[2.620800e+02, 2.674900e+02, 2.667400e+02, 2.631400e+02,
#           2.020863e+06]]]])

# %%
concat_data(read_time_series(timeseries_length=2))
# Out:
#      Symbol        Date    Low.0   High.0   Open.0  Close.0   Volume.0  \
# 0      AAPL  2013-01-03   69.978   71.705   71.553   70.935  154865509
# 1      AAPL  2013-01-04   69.896   71.017   70.745   70.039   97488400
# 2      AAPL  2013-01-07   67.936   69.591   69.375   68.088  164191192
# 3      AAPL  2013-01-08   66.566   68.386   67.446   67.689  133721724
# 4      AAPL  2013-01-09   67.346   68.721   68.375   67.871  126651168
# 5      AAPL  2013-01-10   66.664   67.830   67.533   66.808  112611881
# 6      AAPL  2013-01-11   66.607   68.310   68.287   67.636  166038770
# 7      AAPL  2013-01-14   67.057   67.872   67.331   67.222   96900287
# 8      AAPL  2013-01-15   64.407   65.568   64.945   64.827  202815867
# 9      AAPL  2013-01-16   62.452   64.470   64.382   62.781  242045402
# 10     AAPL  2013-01-17   63.630   65.820   63.907   65.383  190827569
# 11     AAPL  2013-01-18   64.862   65.990   65.931   64.945  125178052
# ...
